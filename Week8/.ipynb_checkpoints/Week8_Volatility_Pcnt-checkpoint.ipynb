# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os
from collections import OrderedDict

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#sorting dict
frames = OrderedDict(sorted(frames.items(), key=lambda x: x[1]['volatility_pcnt'].sum(), reverse=True))

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.plot(df.index, df.volatility_pcnt, color='black')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('USD', size=16)
    ax.set_title('Daily Volatility Percentage', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['volatility_pcnt']])
# Out:
# correlations
# BTG
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.192634              1.0
# XRB
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.256579              1.0
# ZCL
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.317612              1.0
# XVG
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.264614              1.0
# ARK
#                  return_pcnt  volatility_pcnt
# volatility_pcnt      0.06741              1.0
# DGB
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.099881              1.0
# NEO
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.200719              1.0
# SC
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.078556              1.0
# STRAT
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.070154              1.0
# XLM
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.121124              1.0
# BCN
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.083898              1.0
# STEEM
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.133738              1.0
# PIVX
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.045695              1.0
# BTS
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.030297              1.0
# FCT
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.074735              1.0
# QTUM
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.065918              1.0
# LSK
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.087098              1.0
# DCR
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.064831              1.0
# SNT
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.208778              1.0
# GNT
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.230402              1.0
# RHOC
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.177421              1.0
# EOS
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.248314              1.0
# OMG
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.125955              1.0
# WAVES
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.037421              1.0
# DOGE
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.070629              1.0
# BCH
#                  return_pcnt  volatility_pcnt
# volatility_pcnt      0.11321              1.0
# REP
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.071422              1.0
# ZEC
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.040756              1.0
# ZRX
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.279864              1.0
# XRP
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.163397              1.0
# XMR
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.007056              1.0
# LTC
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.072735              1.0
# DASH
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.078078              1.0
# ADA
#                  return_pcnt  volatility_pcnt
# volatility_pcnt      0.36965              1.0
# ETN
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.006356              1.0
# ETH
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.115975              1.0
# BTC
#                  return_pcnt  volatility_pcnt
# volatility_pcnt    -0.127627              1.0
# DRGN
#                  return_pcnt  volatility_pcnt
# volatility_pcnt     0.360864              1.0
