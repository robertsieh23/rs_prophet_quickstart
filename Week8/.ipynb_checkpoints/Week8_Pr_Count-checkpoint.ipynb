# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os
from collections import OrderedDict

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    #frames[coin] = df.set_index('date')
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#sorting dict
frames = OrderedDict(sorted(frames.items(), key=lambda x: x[1]['pr_count'].sum(), reverse=True))

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.pr_count, color='darkblue')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('GitHub Pull Requests', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['pr_count']])
# Out:
# correlations
# BTC
#           return_pcnt  volatility_pcnt
# pr_count    -0.067309         0.058738
# SNT
#           return_pcnt  volatility_pcnt
# pr_count     -0.01175         0.121793
# XMR
#           return_pcnt  volatility_pcnt
# pr_count    -0.002732        -0.096374
# ADA
#           return_pcnt  volatility_pcnt
# pr_count      0.03049          0.09643
# ETH
#           return_pcnt  volatility_pcnt
# pr_count      0.07019        -0.022218
# EOS
#           return_pcnt  volatility_pcnt
# pr_count    -0.047379         0.124995
# GNT
#           return_pcnt  volatility_pcnt
# pr_count    -0.049173         0.129532
# LSK
#           return_pcnt  volatility_pcnt
# pr_count    -0.004439         0.138488
# WAVES
#           return_pcnt  volatility_pcnt
# pr_count     0.114602         0.072224
# STEEM
#           return_pcnt  volatility_pcnt
# pr_count     0.084593         0.012646
# SC
#           return_pcnt  volatility_pcnt
# pr_count     0.008076         0.172368
# DASH
#           return_pcnt  volatility_pcnt
# pr_count     0.003008         0.093177
# REP
#           return_pcnt  volatility_pcnt
# pr_count     0.034553        -0.202679
# DCR
#           return_pcnt  volatility_pcnt
# pr_count     0.026585        -0.045189
# STRAT
#           return_pcnt  volatility_pcnt
# pr_count     0.080699         0.085537
# QTUM
#           return_pcnt  volatility_pcnt
# pr_count     0.037751          0.07256
# RHOC
#           return_pcnt  volatility_pcnt
# pr_count    -0.014843         0.009784
# ZRX
#           return_pcnt  volatility_pcnt
# pr_count    -0.032159         0.052971
# PIVX
#           return_pcnt  volatility_pcnt
# pr_count    -0.079057        -0.009533
# XRB
#           return_pcnt  volatility_pcnt
# pr_count    -0.073322         0.141117
# XRP
#           return_pcnt  volatility_pcnt
# pr_count    -0.012016         0.009806
# ZEC
#           return_pcnt  volatility_pcnt
# pr_count     0.034537         0.075868
# BTS
#           return_pcnt  volatility_pcnt
# pr_count    -0.003228         0.129796
# XLM
#           return_pcnt  volatility_pcnt
# pr_count     0.006243         0.051237
# XVG
#           return_pcnt  volatility_pcnt
# pr_count     0.000906         0.109613
# FCT
#           return_pcnt  volatility_pcnt
# pr_count    -0.065408        -0.003361
# BTG
#           return_pcnt  volatility_pcnt
# pr_count     0.037148         0.185585
# NEO
#           return_pcnt  volatility_pcnt
# pr_count     0.058443        -0.026426
# DOGE
#           return_pcnt  volatility_pcnt
# pr_count    -0.093499         0.034866
# LTC
#           return_pcnt  volatility_pcnt
# pr_count    -0.027723         0.032466
# BCH
#           return_pcnt  volatility_pcnt
# pr_count     0.020552         0.191679
# ARK
#           return_pcnt  volatility_pcnt
# pr_count     0.044593          0.00289
# ZCL
#           return_pcnt  volatility_pcnt
# pr_count    -0.143165         0.091716
# BCN
#           return_pcnt  volatility_pcnt
# pr_count     0.195104         0.229441
# DGB
#           return_pcnt  volatility_pcnt
# pr_count     0.130904         0.203941
# ETN
#           return_pcnt  volatility_pcnt
# pr_count    -0.099702        -0.047442
# OMG
#           return_pcnt  volatility_pcnt
# pr_count    -0.146306         0.092719
# DRGN
#           return_pcnt  volatility_pcnt
# pr_count      0.07748         0.019733
