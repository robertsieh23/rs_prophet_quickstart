# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.commit_del_sum, color='darkred')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('GitHub Commit Deletions', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['commit_del_sum']])
# Out:
# correlations
# DRGN
#                 return_pcnt  volatility_pcnt
# commit_del_sum          NaN              NaN
# BCH
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.081522         0.040023
# BTC
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.017176         0.076151
# XRB
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.062286        -0.023555
# RHOC
#                 return_pcnt  volatility_pcnt
# commit_del_sum     -0.07916         0.003003
# SNT
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.154859         0.195136
# XRP
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.033402        -0.042037
# BTG
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.044288         0.080262
# BCN
#                 return_pcnt  volatility_pcnt
# commit_del_sum    -0.047648        -0.016203
# REP
#                 return_pcnt  volatility_pcnt
# ...
