# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.star_count, color='green')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('GitHub Stargazers', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['star_count']])
# Out:
# correlations
# DRGN
#             return_pcnt  volatility_pcnt
# star_count     0.125202         0.127131
# BCH
#             return_pcnt  volatility_pcnt
# star_count     0.101135         0.547327
# BTC
#             return_pcnt  volatility_pcnt
# star_count     -0.06983         0.447668
# XRB
#             return_pcnt  volatility_pcnt
# star_count     0.116863         0.289833
# RHOC
#             return_pcnt  volatility_pcnt
# star_count    -0.091111        -0.029523
# SNT
#             return_pcnt  volatility_pcnt
# star_count     0.088172          0.32083
# XRP
#             return_pcnt  volatility_pcnt
# star_count     0.105533         0.559633
# BTG
#             return_pcnt  volatility_pcnt
# star_count      0.02796         0.326904
# BCN
#             return_pcnt  volatility_pcnt
# star_count     0.129227         0.161316
# REP
#             return_pcnt  volatility_pcnt
# star_count    -0.040832         0.127573
# STEEM
#             return_pcnt  volatility_pcnt
# star_count    -0.030445         0.258899
# BTS
#             return_pcnt  volatility_pcnt
# star_count    -0.023758         0.239195
# LSK
#             return_pcnt  volatility_pcnt
# star_count     0.130363         0.076058
# WAVES
#             return_pcnt  volatility_pcnt
# star_count     0.074974         0.065408
# DGB
#             return_pcnt  volatility_pcnt
# star_count     0.114089         0.381884
# ZCL
#             return_pcnt  volatility_pcnt
# star_count     0.313695         0.437573
# XMR
#             return_pcnt  volatility_pcnt
# star_count     0.037481         0.260701
# SC
#             return_pcnt  volatility_pcnt
# star_count     0.153514         0.268148
# XLM
#             return_pcnt  volatility_pcnt
# star_count     0.054407         0.256837
# NEO
#             return_pcnt  volatility_pcnt
# star_count    -0.041296         0.391551
# GNT
#             return_pcnt  volatility_pcnt
# star_count    -0.020791         0.217075
# PIVX
#             return_pcnt  volatility_pcnt
# star_count     0.094769         0.145815
# OMG
#             return_pcnt  volatility_pcnt
# star_count     0.076447         0.089342
# ETN
#             return_pcnt  volatility_pcnt
# star_count    -0.030344         0.346533
# EOS
#             return_pcnt  volatility_pcnt
# star_count     0.077331         0.301207
# STRAT
#             return_pcnt  volatility_pcnt
# star_count     0.041198        -0.051604
# XVG
#             return_pcnt  volatility_pcnt
# star_count    -0.094345         0.261875
# ETH
#             return_pcnt  volatility_pcnt
# star_count    -0.010892         0.296467
# QTUM
#             return_pcnt  volatility_pcnt
# star_count    -0.013741         0.149968
# ARK
#             return_pcnt  volatility_pcnt
# star_count     -0.06586         0.026471
# ZEC
#             return_pcnt  volatility_pcnt
# star_count     0.021522         0.346535
# DASH
#             return_pcnt  volatility_pcnt
# star_count     0.134459         0.250223
# DCR
#             return_pcnt  volatility_pcnt
# star_count     0.002161        -0.034048
# FCT
#             return_pcnt  volatility_pcnt
# star_count    -0.059802         0.245646
# ADA
#             return_pcnt  volatility_pcnt
# star_count       0.1377          0.33732
# LTC
#             return_pcnt  volatility_pcnt
# star_count      0.17587         0.465318
# ZRX
#             return_pcnt  volatility_pcnt
# star_count     0.090161         0.273862
# DOGE
#             return_pcnt  volatility_pcnt
# star_count     0.153867         0.361428
