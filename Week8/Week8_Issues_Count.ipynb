# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.issues_count, color='darkred')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('GitHub Issues', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['issues_count']])
# Out:
# correlations
# DRGN
#               return_pcnt  volatility_pcnt
# issues_count     0.073759        -0.068884
# BCH
#               return_pcnt  volatility_pcnt
# issues_count    -0.044622         0.409527
# BTC
#               return_pcnt  volatility_pcnt
# issues_count    -0.051329         0.102122
# XRB
#               return_pcnt  volatility_pcnt
# issues_count     0.002266         0.229576
# RHOC
#               return_pcnt  volatility_pcnt
# issues_count     -0.02236         -0.00176
# SNT
#               return_pcnt  volatility_pcnt
# issues_count    -0.032605         0.112431
# XRP
#               return_pcnt  volatility_pcnt
# issues_count     0.038485         0.060176
# BTG
#               return_pcnt  volatility_pcnt
# issues_count     -0.01952          0.27739
# BCN
#               return_pcnt  volatility_pcnt
# issues_count     0.035809         0.234007
# REP
#               return_pcnt  volatility_pcnt
# issues_count     0.027634        -0.200245
# STEEM
#               return_pcnt  volatility_pcnt
# issues_count      0.04911         0.014346
# BTS
#               return_pcnt  volatility_pcnt
# issues_count    -0.033141         0.150376
# LSK
#               return_pcnt  volatility_pcnt
# issues_count    -0.000362         0.169963
# WAVES
#               return_pcnt  volatility_pcnt
# issues_count     0.092216         0.090066
# DGB
#               return_pcnt  volatility_pcnt
# issues_count     0.032296         0.131764
# ZCL
#               return_pcnt  volatility_pcnt
# issues_count     0.019898         0.378138
# XMR
#               return_pcnt  volatility_pcnt
# issues_count     0.005635        -0.024935
# SC
#               return_pcnt  volatility_pcnt
# issues_count      0.02114         0.150601
# XLM
#               return_pcnt  volatility_pcnt
# issues_count     0.056366         0.123201
# NEO
#               return_pcnt  volatility_pcnt
# issues_count     0.062521         0.038239
# GNT
#               return_pcnt  volatility_pcnt
# issues_count    -0.011188         0.117427
# PIVX
#               return_pcnt  volatility_pcnt
# issues_count    -0.091395        -0.058229
# OMG
#               return_pcnt  volatility_pcnt
# issues_count    -0.143956         0.079854
# ETN
#               return_pcnt  volatility_pcnt
# issues_count    -0.087801        -0.074351
# EOS
#               return_pcnt  volatility_pcnt
# issues_count     -0.05078         0.096014
# STRAT
#               return_pcnt  volatility_pcnt
# issues_count     0.133261           0.0747
# XVG
#               return_pcnt  volatility_pcnt
# issues_count    -0.089148         0.140857
# ETH
#               return_pcnt  volatility_pcnt
# issues_count     0.005154         0.023857
# QTUM
#               return_pcnt  volatility_pcnt
# issues_count      0.06667         0.103612
# ARK
#               return_pcnt  volatility_pcnt
# issues_count     0.037839        -0.016696
# ZEC
#               return_pcnt  volatility_pcnt
# issues_count     0.053399         0.121669
# DASH
#               return_pcnt  volatility_pcnt
# issues_count    -0.017328         0.166629
# DCR
#               return_pcnt  volatility_pcnt
# issues_count     0.016439        -0.044734
# FCT
#               return_pcnt  volatility_pcnt
# issues_count    -0.077701        -0.004325
# ADA
#               return_pcnt  volatility_pcnt
# issues_count     0.038167          0.11633
# LTC
#               return_pcnt  volatility_pcnt
# issues_count     0.021217         0.044618
# ZRX
#               return_pcnt  volatility_pcnt
# issues_count     0.008781         0.099665
# DOGE
#               return_pcnt  volatility_pcnt
# issues_count    -0.072847         0.100846
