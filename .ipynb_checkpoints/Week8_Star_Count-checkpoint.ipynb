# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.commit_count, color='lightcoral')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('Git Commit', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['commit_count']])
# Out:
# correlations
# DRGN
#               return_pcnt  volatility_pcnt
# commit_count          NaN              NaN
# BCH
#               return_pcnt  volatility_pcnt
# commit_count    -0.121129         0.041748
# BTC
#               return_pcnt  volatility_pcnt
# commit_count     0.030351         0.041916
# XRB
#               return_pcnt  volatility_pcnt
# commit_count    -0.122763         0.119701
# RHOC
#               return_pcnt  volatility_pcnt
# commit_count     0.009265         0.000978
# SNT
#               return_pcnt  volatility_pcnt
# commit_count    -0.029714         0.049845
# XRP
#               return_pcnt  volatility_pcnt
# commit_count    -0.032256         0.028748
# BTG
#               return_pcnt  volatility_pcnt
# commit_count    -0.070949         0.099268
# BCN
#               return_pcnt  volatility_pcnt
# commit_count     0.036187         0.031935
# REP
#               return_pcnt  volatility_pcnt
# commit_count     0.045016        -0.200861
# STEEM
#               return_pcnt  volatility_pcnt
# commit_count     0.059117         0.052338
# BTS
#               return_pcnt  volatility_pcnt
# commit_count     0.130102        -0.035033
# LSK
#               return_pcnt  volatility_pcnt
# commit_count     -0.03363         0.036489
# WAVES
#               return_pcnt  volatility_pcnt
# commit_count     0.045735         0.050962
# DGB
#               return_pcnt  volatility_pcnt
# commit_count     0.032731        -0.012306
# ZCL
#               return_pcnt  volatility_pcnt
# commit_count     0.013507        -0.002029
# XMR
#               return_pcnt  volatility_pcnt
# commit_count     0.022658        -0.061282
# SC
#               return_pcnt  volatility_pcnt
# commit_count    -0.092009         0.099912
# XLM
#               return_pcnt  volatility_pcnt
# commit_count     0.123876          0.16994
# NEO
#               return_pcnt  volatility_pcnt
# commit_count    -0.089138        -0.046779
# GNT
#               return_pcnt  volatility_pcnt
# commit_count    -0.031833         0.068235
# PIVX
#               return_pcnt  volatility_pcnt
# commit_count    -0.027836        -0.072596
# OMG
#               return_pcnt  volatility_pcnt
# commit_count    -0.132873         0.124706
# ETN
#               return_pcnt  volatility_pcnt
# commit_count     0.011677        -0.004858
# EOS
#               return_pcnt  volatility_pcnt
# commit_count    -0.054174         0.127905
# STRAT
#               return_pcnt  volatility_pcnt
# commit_count      0.12843         0.136735
# XVG
#               return_pcnt  volatility_pcnt
# commit_count    -0.017515         0.114027
# ETH
#               return_pcnt  volatility_pcnt
# commit_count     0.027598         0.065999
# QTUM
#               return_pcnt  volatility_pcnt
# commit_count     0.034701         0.058721
# ARK
#               return_pcnt  volatility_pcnt
# commit_count     0.006117         0.004096
# ZEC
#               return_pcnt  volatility_pcnt
# commit_count    -0.046984         0.119403
# DASH
#               return_pcnt  volatility_pcnt
# commit_count     0.038579        -0.092368
# DCR
#               return_pcnt  volatility_pcnt
# commit_count     0.061663         0.030906
# FCT
#               return_pcnt  volatility_pcnt
# commit_count    -0.015478        -0.005267
# ADA
#               return_pcnt  volatility_pcnt
# commit_count    -0.016352         0.033355
# LTC
#               return_pcnt  volatility_pcnt
# commit_count     0.014267        -0.092949
# ZRX
#               return_pcnt  volatility_pcnt
# commit_count    -0.028801         0.028792
# DOGE
#               return_pcnt  volatility_pcnt
# commit_count    -0.141576         0.082886
