# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import os

# %%
frames = {}
path = 'github_data/'
for filename in os.listdir(path):
    coin = filename.split('.')[0]
    frames[coin] = pd.read_csv(path + filename)

# %%
for coin, df in frames.items():
    frames[coin]['return_pcnt'] = (df.close - df.open) / df.close
    frames[coin]['volatility_pcnt'] = (df.high - df.low) / ((df.high + df.low) / 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
for coin, df in frames.items():
    
    fig = plt.figure(figsize=(15,5))
    fig.suptitle(coin, size=20)
    ax = plt.gca()
    plt.bar(df.index, df.commit_add_sum, color='darkred')
    for ix, label in enumerate(ax.xaxis.get_ticklabels()):
        label.set_visible(True) if ix % 80 == 0 else label.set_visible(False)
    ax.set_ylabel('Count', size=16)
    ax.set_title('GitHub Commit Additions', size=16)
    plt.show()

# %%
print("correlations")
for coin, df in frames.items():
    print(coin)
    print(df.corr()[['return_pcnt', 'volatility_pcnt']].loc[['commit_add_sum']])
# Out:
# correlations
# DRGN
#                 return_pcnt  volatility_pcnt
# commit_add_sum          NaN              NaN
# BCH
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.097188         0.046483
# BTC
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.124139         0.045182
# XRB
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.085964        -0.026059
# RHOC
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.028075         0.028285
# SNT
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.050855         0.034649
# XRP
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.006388        -0.044315
# BTG
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.018767         0.115035
# BCN
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.047853        -0.011252
# REP
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.080931        -0.015867
# STEEM
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.038452         0.107792
# BTS
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.088111        -0.050995
# LSK
#                 return_pcnt  volatility_pcnt
# commit_add_sum       0.0628         0.238084
# WAVES
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.051779         0.016228
# DGB
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.022343        -0.035983
# ZCL
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.009063         0.000045
# XMR
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.049868        -0.005875
# SC
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.118343         0.114337
# XLM
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.068455         0.057174
# NEO
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.035396         0.048293
# GNT
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.094198         0.115251
# PIVX
#                 return_pcnt  volatility_pcnt
# commit_add_sum      0.07845        -0.033049
# OMG
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.007132         0.179513
# ETN
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.035105         0.057968
# EOS
#                 return_pcnt  volatility_pcnt
# commit_add_sum      0.07081         0.031472
# STRAT
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.102606         0.053314
# XVG
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.304248         0.204178
# ETH
#                 return_pcnt  volatility_pcnt
# commit_add_sum      0.02543         0.025475
# QTUM
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.039449        -0.040188
# ARK
#                 return_pcnt  volatility_pcnt
# commit_add_sum     -0.00146        -0.019212
# ZEC
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.010485        -0.045011
# DASH
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.213791         0.199216
# DCR
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.007121        -0.086424
# FCT
#                 return_pcnt  volatility_pcnt
# commit_add_sum     -0.00511        -0.050257
# ADA
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.088498         0.095878
# LTC
#                 return_pcnt  volatility_pcnt
# commit_add_sum     0.062627        -0.058018
# ZRX
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.107761         0.050128
# DOGE
#                 return_pcnt  volatility_pcnt
# commit_add_sum    -0.141576         0.082886
